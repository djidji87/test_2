# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
import ssl
# следующая строчка подключает сертификат для защищенного соединения
ssl._create_default_https_context = ssl._create_unverified_context
url='http://yustiks.ru/dataset/housing.csv'
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'TAX', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(url,  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data['MEDV'].unique()
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 13.6, 19.6, 15.2, 14.5,
#        15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 13.2, 13.1, 13.5, 20. ,
#        24.7, 30.8, 34.9, 26.6, 25.3, 21.2, 19.3, 14.4, 19.4, 19.7, 20.5,
#        25. , 23.4, 35.4, 31.6, 23.3, 18.7, 16. , 22.2, 33. , 23.5, 22. ,
#        17.4, 20.9, 24.2, 22.8, 24.1, 21.4, 20.8, 20.3, 28. , 23.9, 24.8,
#        22.5, 23.6, 22.6, 20.6, 28.4, 38.7, 43.8, 33.2, 27.5, 26.5, 18.6,
#        20.1, 19.5, 19.8, 18.8, 18.5, 18.3, 19.2, 17.3, 15.7, 16.2, 18. ,
#        14.3, 23. , 18.1, 17.1, 13.3, 17.8, 14. , 13.4, 11.8, 13.8, 14.6,
#        15.4, 21.5, 15.3, 17. , 41.3, 24.3, 27. , 50. , 22.7, 23.8, 22.3,
#        19.1, 29.4, 23.2, 24.6, 29.9, 37.2, 39.8, 37.9, 32.5, 26.4, 29.6,
#        32. , 29.8, 37. , 30.5, 36.4, 31.1, 29.1, 33.3, 30.3, 34.6, 32.9,
#        42.3, 48.5, 24.4, 22.4, 28.1, 23.7, 26.7, 30.1, 44.8, 37.6, 46.7,
# ...

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['ZN'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('ZN')
plt.title('Частотный график ZN (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Нормальное распределение. График к указанным типам не относится.')
# Out:
# Нормальное распределение. График к указанным типам не относится.

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['INDUS'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('INDUS')
plt.title('Частотный график INDUS (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Дискретное распределение. График к указанным типам не относится.')
# Out:
# Нормальное распределение. График к указанным типам не относится.

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['CHAS'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('CHAS')
plt.title('Частотный график CHAS (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Дискретное распределение. Распределение Бернулли.')
# Out:
# Дискретное распределение. График к указанным типам не относится.

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['NOX'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('NOX')
plt.title('Частотный график NOX (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Дискретное распределение. График к указанным типам не относится.')
# Out:
# Нормальное распределение. Бернулли.

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['RM'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('RM')
plt.title('Частотный график RM (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Дискретное распределение. Биномиальное распределение.')
# Out:
# Дискретное распределение. График к указанным типам не относится.

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['AGE'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('AGE')
plt.title('Частотный график AGE (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Дискретное распределение. Похоже на обратное геометрическео распределение.')
# Out:
# Дискретное распределение. Нормальное.

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['DIS'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('DIS')
plt.title('Частотный график DIS (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Дискретное распределение. Геометрическое распределение.')
# Out:
# Дискретное распределение. Похоже на обратное геометрическое распределение.

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['TAX'], 100, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('TAX')
plt.title('Частотный график TAX (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Нормальное распределение. Закономерности распределения нет.')
# Out:
# Нормальное распределение. Есть сходство с логнормаьлным распределением, но правый столбец все отменяет - закономерности распределения нет.

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['PTRATIO'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('PTRATIO')
plt.title('Частотный график PTRATIO (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Нормальное распределение. Закономерности распределения нет.')
# Out:
# Нормальное распределение. Закономерности распределения нет.

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['B'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('B')
plt.title('Частотный график B (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Дискретное распределение. Закономерности распределения нет.')
# Out:
# Дискретное распределение. Закономерности распределения нет.

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['LSTAT'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('LSTAT')
plt.title('Частотный график LSTAT (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Дискретное распределение. Похоже на негативное биномиаьлное распределение.')
# Out:
# Дискретное распределение. Закономерности распределения нет.

# %%
# plt.hist - строит частотный график выборки, разбивая значения выборки на равные интервалы
n, bins, patches = plt.hist(data['MEDV'], 10, facecolor='g')

plt.xlabel('frequency')
plt.ylabel('MEDV')
plt.title('Частотный график MEDV (разбиение интервала по 15 элементов)')
plt.grid(True)
plt.show()
print('Дискретное распределение. Похоже на биномиаьлное или гипергеометрическое распределение.')
# Out:
# Дискретное распределение. Похоже на негативное биномиаьлное распределение.

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
from sklearn.linear_model import LinearRegression

MEDV = data['MEDV']
LSTAT = data['LSTAT']
# параметр fit_reg - строит линию регрессии для двух выборок
sns.regplot(x=MEDV, y=LSTAT, data=data, fit_reg=True)
plt.xlabel('MEDV')
plt.ylabel('LSTAT')
plt.title('Корреляционная зависимость двух выборок')
plt.grid(False)
plt.show()
freedom = np.array(MEDV).reshape(-1,1)
positive = np.array(LSTAT).reshape(-1,1)
model = LinearRegression()

from sklearn.model_selection import train_test_split

# x = freedom,
# y = positive
X_train, X_test, y_train, y_test = train_test_split(
    freedom,
    positive,
    test_size = 0.2
)

model.fit(X_train, y_train)

predicted_y = model.predict(X_test)

print('Ошибка модели составляет{:.2%}'.format(model.score(X_test, y_test)))

plt.xlabel('freedom')
plt.ylabel('positive affect')
plt.title('Линейная регрессия от одной переменной')
# Построим прямую для регрессии
# Создадим 100 точек для предсказаний
x = np.linspace(-50, 200, 100)
# Посчитаем предсказанные значения
# y = kx + b
# k = model.coef_
# b = model.intercept_
y = model.coef_*x + model.intercept_
y = np.transpose(y)
plt.plot(x,y)
plt.plot(X_train, y_train, 'r.')
plt.plot(X_test, y_test, 'go')
plt.xlim(-50,200)
plt.ylim(-50,200)
plt.legend(['Прямая линейной регрессии', 'Тренировочные данные', 'Тестовые данные'])
plt.show()
# Out:
# Ошибка модели составляет62.16%

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 0                     Finland       1             4             41.0
# 1                     Denmark       2            13             24.0
# 2                      Norway       3             8             16.0
# 3                     Iceland       4             9              3.0
# 4                 Netherlands       5             1             12.0
# ..                        ...     ...           ...              ...
# 151                    Rwanda     152            63             54.0
# 152                  Tanzania     153           122             78.0
# 153               Afghanistan     154            25            152.0
# 154  Central African Republic     155           117            132.0
# 155               South Sudan     156           140            127.0
#
#      Negative affect  Social support  Freedom  Corruption  Generosity  \
# ...

# %%
print('Матрица ковариаций попарно')
data.cov()
# Out:
# Матрица ковариаций попарно
#                                Ladder  SD of Ladder  Positive affect  \
# Ladder                    2041.000000   1100.838710       995.928571
# SD of Ladder              1100.838710   2041.000000       173.694805
# Positive affect            995.928571    173.694805      2015.000000
# Negative affect           1061.207792   1259.805195       785.240260
# Social support            1657.428571   1219.519481       778.331169
# Freedom                   1108.090909    512.363636      1373.766234
# Corruption                 370.874150    506.897959       405.292517
# Generosity                1008.948052    797.779221       715.077922
# Log of GDP\nper capita    1615.000000   1254.526490       586.120000
# Healthy life\nexpectancy  1613.369128   1208.026846       647.908897
#
#                           Negative affect  Social support      Freedom  \
# Ladder                        1061.207792     1657.428571  1108.090909
# ...

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop).

# %%
count_nan = len(data) - data.count()
print('В табилце всего отсутствующих значений {}'.format(count_nan.sum()))
if data['Country (region)'].isna().sum() > 0:
    data['Country (region)'].dropna()
    print('Все отсутствующиt значения удалены')
else:
    print('В столбце "Country" нет отсутствующих значений')
# Out:
# В табилце всего отсутствующих значений 23
# В столбце "Country" нет отсутствующих значений

# %% [markdown]
# Сколько стран в выборке? Написать ответ.

# %%
print('В данной выборке представленно {} стран'.format(len(data['Country (region)'].unique())))
# Out:
# В данной выборке представленно 156 стран

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы?

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->матрица корреляций
# gcf() - получение текущей фигуры
fig=plt.gcf()
# set_size_inches() - установить размер фигуры
fig.set_size_inches(11,11)
plt.show()

# %%
sns.pairplot(data)

# %%
#Худшая корреляция со всеми данынми у столбца 'Corruption'
#'Freedom' и 'Generosity' также мало коррелируют с данными из табилцы
#Полностью лишены корреляции 'Positive affect' и 'SD of Ladder'
#Данные из 'Log of GDP\nper capita' и 'Healthy life\nexpectancy' лучше всего коррелируют с другими столбцами. Между ними же лучшая корреляяция в табилце

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
data_bern = stats.bernoulli.rvs(size=10,p=0.5)
ax= sns.distplot(data_bern,
                 kde=False,
                 color="skyblue",
                 hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Бернулли', ylabel='Вероятность')
plt.title('Плотность рапределения Бернулли')
plt.show()

# %% [markdown]
# моделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. Почему график изменился? Почему можно применить центральную предельную теорему?

# %%
data_binom = stats.binom.rvs(n=100,p=0.5,size=1000)
ax = sns.distplot(data_binom,
                  kde=False,
                  color='blue')
ax.set(xlabel='Биноминальное распределение', ylabel='Частота (плотность)')
# Out:
# [Text(0, 0.5, 'Частота (плотность)'),
#  Text(0.5, 0, 'Биноминальное распределение')]

# %% [markdown]
# График изменился т.к. в первом случае мы работаем с 1 эксперементом, а во втором с множеством эксперементов.

# %% [markdown]
# Центральная предельная теорема применима т.к. ее условия выполнены. У нас:
# 1. Достаточно большое количество слабо зависимых случайных величин
# 2. Величины имеют примерно одинаковый масштаб
# 3. Величины имеют распределение, близкое к нормальному
